# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline

# %%
data = pd.read_csv("Data/zomato.csv", encoding = "latin-1")

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data.shape
# Out:
# (9551, 21)

# %%
data.iloc[:, 0:10]
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
data.iloc[:, 10:20]
# Out:
#       Average Cost for two          Currency Has Table booking  \
# 0                     1100  Botswana Pula(P)               Yes
# 1                     1200  Botswana Pula(P)               Yes
# 2                     4000  Botswana Pula(P)               Yes
# 3                     1500  Botswana Pula(P)                No
# 4                     1500  Botswana Pula(P)               Yes
# ...                    ...               ...               ...
# 9546                    80  Turkish Lira(TL)                No
# 9547                   105  Turkish Lira(TL)                No
# 9548                   170  Turkish Lira(TL)                No
# 9549                   120  Turkish Lira(TL)                No
# 9550                    55  Turkish Lira(TL)                No
#
#      Has Online delivery Is delivering now Switch to order menu  Price range  \
# 0                     No                No                   No            3
# ...

# %%
country_code  = data["Country Code"].unique()

# %%
country_code
# Out:
# array([162,  30, 216,  14,  37, 184, 214,   1,  94, 148, 215, 166, 189,
#        191, 208])

# %%
country_code.sort()

# %%
country_code
# Out:
# array([  1,  14,  30,  37,  94, 148, 162, 166, 184, 189, 191, 208, 214,
#        215, 216])

# %%
gp = data.groupby("Country Code")[["Currency", "City"]]

# %%
# 1. India
# 14. Australia
# 30. Brazil
# 37. Canada
# 94. Indonesia
# 148.newzealand
# 162.philippines
# 166.Quatar
# 184.Singapore
# 189.South Africa
# 191.Sri Lanka
# 208.Turkey
# 214.Abu Dhabi
# 215.Uk
# 216.USA

# %%
gp.get_group(1)
# Out:
#                 Currency   City
# 624   Indian Rupees(Rs.)   Agra
# 625   Indian Rupees(Rs.)   Agra
# 626   Indian Rupees(Rs.)   Agra
# 627   Indian Rupees(Rs.)   Agra
# 628   Indian Rupees(Rs.)   Agra
# ...                  ...    ...
# 9271  Indian Rupees(Rs.)  Vizag
# 9272  Indian Rupees(Rs.)  Vizag
# 9273  Indian Rupees(Rs.)  Vizag
# 9274  Indian Rupees(Rs.)  Vizag
# 9275  Indian Rupees(Rs.)  Vizag
#
# [8652 rows x 2 columns]

# %%
gp.get_group(14)
# Out:
#       Currency             City
# 102  Dollar($)         Armidale
# 143  Dollar($)         Balingup
# 144  Dollar($)       Beechworth
# 269  Dollar($)      Dicky Beach
# 290  Dollar($)     East Ballina
# 292  Dollar($)          Flaxton
# 293  Dollar($)          Forrest
# 314  Dollar($)  Hepburn Springs
# 315  Dollar($)  Hepburn Springs
# 316  Dollar($)        Huskisson
# 317  Dollar($)        Inverloch
# 318  Dollar($)   Lakes Entrance
# 321  Dollar($)             Lorn
# 322  Dollar($)          Macedon
# 343  Dollar($)         Mayfield
# 345  Dollar($)  Middleton Beach
# 348  Dollar($)        Montville
# 370  Dollar($)        Palm Cove
# 371  Dollar($)      Paynesville
# 372  Dollar($)           Penola
# 393  Dollar($)   Phillip Island
# 516  Dollar($)          Tanunda
# 517  Dollar($)    Trentham East
# 539  Dollar($)    Victor Harbor

# %%
gp.get_group(30)
# Out:
#               Currency            City
# 22  Brazilian Real(R$)       Brasí_lia
# 23  Brazilian Real(R$)       Brasí_lia
# 24  Brazilian Real(R$)       Brasí_lia
# 25  Brazilian Real(R$)       Brasí_lia
# 26  Brazilian Real(R$)       Brasí_lia
# 27  Brazilian Real(R$)       Brasí_lia
# 28  Brazilian Real(R$)       Brasí_lia
# 29  Brazilian Real(R$)       Brasí_lia
# 30  Brazilian Real(R$)       Brasí_lia
# 31  Brazilian Real(R$)       Brasí_lia
# 32  Brazilian Real(R$)       Brasí_lia
# 33  Brazilian Real(R$)       Brasí_lia
# 34  Brazilian Real(R$)       Brasí_lia
# 35  Brazilian Real(R$)       Brasí_lia
# 36  Brazilian Real(R$)       Brasí_lia
# 37  Brazilian Real(R$)       Brasí_lia
# 38  Brazilian Real(R$)       Brasí_lia
# 39  Brazilian Real(R$)       Brasí_lia
# 40  Brazilian Real(R$)       Brasí_lia
# 41  Brazilian Real(R$)       Brasí_lia
# 42  Brazilian Real(R$)  Rio de Janeiro
# 43  Brazilian Real(R$)  Rio de Janeiro
# 44  Brazilian Real(R$)  Rio de Janeiro
# ...

# %%
gp.get_group(37)
# Out:
#       Currency              City
# 185  Dollar($)      Chatham-Kent
# 208  Dollar($)           Consort
# 540  Dollar($)  Vineland Station
# 563  Dollar($)           Yorkton

# %%
gp.get_group(94)
# Out:
#                     Currency       City
# 9276  Indonesian Rupiah(IDR)    Bandung
# 9277  Indonesian Rupiah(IDR)      Bogor
# 9278  Indonesian Rupiah(IDR)      Bogor
# 9279  Indonesian Rupiah(IDR)    Jakarta
# 9280  Indonesian Rupiah(IDR)    Jakarta
# 9281  Indonesian Rupiah(IDR)    Jakarta
# 9282  Indonesian Rupiah(IDR)    Jakarta
# 9283  Indonesian Rupiah(IDR)    Jakarta
# 9284  Indonesian Rupiah(IDR)    Jakarta
# 9285  Indonesian Rupiah(IDR)    Jakarta
# 9286  Indonesian Rupiah(IDR)    Jakarta
# 9287  Indonesian Rupiah(IDR)    Jakarta
# 9288  Indonesian Rupiah(IDR)    Jakarta
# 9289  Indonesian Rupiah(IDR)    Jakarta
# 9290  Indonesian Rupiah(IDR)    Jakarta
# 9291  Indonesian Rupiah(IDR)    Jakarta
# 9292  Indonesian Rupiah(IDR)    Jakarta
# 9293  Indonesian Rupiah(IDR)    Jakarta
# 9294  Indonesian Rupiah(IDR)    Jakarta
# 9295  Indonesian Rupiah(IDR)  Tangerang
# 9296  Indonesian Rupiah(IDR)  Tangerang

# %%
gp.get_group(148)
# Out:
#            Currency             City
# 9297  NewZealand($)         Auckland
# 9298  NewZealand($)         Auckland
# 9299  NewZealand($)         Auckland
# 9300  NewZealand($)         Auckland
# 9301  NewZealand($)         Auckland
# 9302  NewZealand($)         Auckland
# 9303  NewZealand($)         Auckland
# 9304  NewZealand($)         Auckland
# 9305  NewZealand($)         Auckland
# 9306  NewZealand($)         Auckland
# 9307  NewZealand($)         Auckland
# 9308  NewZealand($)         Auckland
# 9309  NewZealand($)         Auckland
# 9310  NewZealand($)         Auckland
# 9311  NewZealand($)         Auckland
# 9312  NewZealand($)         Auckland
# 9313  NewZealand($)         Auckland
# 9314  NewZealand($)         Auckland
# 9315  NewZealand($)         Auckland
# 9316  NewZealand($)         Auckland
# 9317  NewZealand($)  Wellington City
# 9318  NewZealand($)  Wellington City
# 9319  NewZealand($)  Wellington City
# 9320  NewZealand($)  Wellington City
# ...

# %%
gp.get_group(162)
# Out:
#             Currency              City
# 0   Botswana Pula(P)       Makati City
# 1   Botswana Pula(P)       Makati City
# 2   Botswana Pula(P)  Mandaluyong City
# 3   Botswana Pula(P)  Mandaluyong City
# 4   Botswana Pula(P)  Mandaluyong City
# 5   Botswana Pula(P)  Mandaluyong City
# 6   Botswana Pula(P)        Pasay City
# 7   Botswana Pula(P)        Pasay City
# 8   Botswana Pula(P)        Pasay City
# 9   Botswana Pula(P)        Pasig City
# 10  Botswana Pula(P)        Pasig City
# 11  Botswana Pula(P)        Pasig City
# 12  Botswana Pula(P)       Quezon City
# 13  Botswana Pula(P)     San Juan City
# 14  Botswana Pula(P)     San Juan City
# 15  Botswana Pula(P)        Santa Rosa
# 16  Botswana Pula(P)        Santa Rosa
# 17  Botswana Pula(P)     Tagaytay City
# 18  Botswana Pula(P)       Taguig City
# 19  Botswana Pula(P)       Taguig City
# 20  Botswana Pula(P)       Taguig City
# 21  Botswana Pula(P)       Taguig City

# %%
gp.get_group(166)
# Out:
#              Currency  City
# 9417  Qatari Rial(QR)  Doha
# 9418  Qatari Rial(QR)  Doha
# 9419  Qatari Rial(QR)  Doha
# 9420  Qatari Rial(QR)  Doha
# 9421  Qatari Rial(QR)  Doha
# 9422  Qatari Rial(QR)  Doha
# 9423  Qatari Rial(QR)  Doha
# 9424  Qatari Rial(QR)  Doha
# 9425  Qatari Rial(QR)  Doha
# 9426  Qatari Rial(QR)  Doha
# 9427  Qatari Rial(QR)  Doha
# 9428  Qatari Rial(QR)  Doha
# 9429  Qatari Rial(QR)  Doha
# 9430  Qatari Rial(QR)  Doha
# 9431  Qatari Rial(QR)  Doha
# 9432  Qatari Rial(QR)  Doha
# 9433  Qatari Rial(QR)  Doha
# 9434  Qatari Rial(QR)  Doha
# 9435  Qatari Rial(QR)  Doha
# 9436  Qatari Rial(QR)  Doha

# %%
gp.get_group(184)
# Out:
#       Currency       City
# 456  Dollar($)  Singapore
# 457  Dollar($)  Singapore
# 458  Dollar($)  Singapore
# 459  Dollar($)  Singapore
# 460  Dollar($)  Singapore
# 461  Dollar($)  Singapore
# 462  Dollar($)  Singapore
# 463  Dollar($)  Singapore
# 464  Dollar($)  Singapore
# 465  Dollar($)  Singapore
# 466  Dollar($)  Singapore
# 467  Dollar($)  Singapore
# 468  Dollar($)  Singapore
# 469  Dollar($)  Singapore
# 470  Dollar($)  Singapore
# 471  Dollar($)  Singapore
# 472  Dollar($)  Singapore
# 473  Dollar($)  Singapore
# 474  Dollar($)  Singapore
# 475  Dollar($)  Singapore

# %%
gp.get_group(189)
# Out:
#      Currency          City
# 9437  Rand(R)     Cape Town
# 9438  Rand(R)     Cape Town
# 9439  Rand(R)     Cape Town
# 9440  Rand(R)     Cape Town
# 9441  Rand(R)     Cape Town
# 9442  Rand(R)     Cape Town
# 9443  Rand(R)     Cape Town
# 9444  Rand(R)     Cape Town
# 9445  Rand(R)     Cape Town
# 9446  Rand(R)     Cape Town
# 9447  Rand(R)     Cape Town
# 9448  Rand(R)     Cape Town
# 9449  Rand(R)     Cape Town
# 9450  Rand(R)     Cape Town
# 9451  Rand(R)     Cape Town
# 9452  Rand(R)     Cape Town
# 9453  Rand(R)     Cape Town
# 9454  Rand(R)     Cape Town
# 9455  Rand(R)     Cape Town
# 9456  Rand(R)     Cape Town
# 9457  Rand(R)    Inner City
# 9458  Rand(R)    Inner City
# 9459  Rand(R)  Johannesburg
# 9460  Rand(R)  Johannesburg
# 9461  Rand(R)  Johannesburg
# 9462  Rand(R)  Johannesburg
# 9463  Rand(R)  Johannesburg
# 9464  Rand(R)  Johannesburg
# 9465  Rand(R)      Pretoria
# 9466  Rand(R)      Pretoria
# 9467  Rand(R)      Pretoria
# 9468  Rand(R)      Pretoria
# ...

# %%
gp.get_group(191)
# Out:
#                    Currency     City
# 9497  Sri Lankan Rupee(LKR)  Colombo
# 9498  Sri Lankan Rupee(LKR)  Colombo
# 9499  Sri Lankan Rupee(LKR)  Colombo
# 9500  Sri Lankan Rupee(LKR)  Colombo
# 9501  Sri Lankan Rupee(LKR)  Colombo
# 9502  Sri Lankan Rupee(LKR)  Colombo
# 9503  Sri Lankan Rupee(LKR)  Colombo
# 9504  Sri Lankan Rupee(LKR)  Colombo
# 9505  Sri Lankan Rupee(LKR)  Colombo
# 9506  Sri Lankan Rupee(LKR)  Colombo
# 9507  Sri Lankan Rupee(LKR)  Colombo
# 9508  Sri Lankan Rupee(LKR)  Colombo
# 9509  Sri Lankan Rupee(LKR)  Colombo
# 9510  Sri Lankan Rupee(LKR)  Colombo
# 9511  Sri Lankan Rupee(LKR)  Colombo
# 9512  Sri Lankan Rupee(LKR)  Colombo
# 9513  Sri Lankan Rupee(LKR)  Colombo
# 9514  Sri Lankan Rupee(LKR)  Colombo
# 9515  Sri Lankan Rupee(LKR)  Colombo
# 9516  Sri Lankan Rupee(LKR)  Colombo

# %%
gp.get_group(208)
# Out:
#               Currency       City
# 9517  Turkish Lira(TL)     Ankara
# 9518  Turkish Lira(TL)     Ankara
# 9519  Turkish Lira(TL)     Ankara
# 9520  Turkish Lira(TL)     Ankara
# 9521  Turkish Lira(TL)     Ankara
# 9522  Turkish Lira(TL)     Ankara
# 9523  Turkish Lira(TL)     Ankara
# 9524  Turkish Lira(TL)     Ankara
# 9525  Turkish Lira(TL)     Ankara
# 9526  Turkish Lira(TL)     Ankara
# 9527  Turkish Lira(TL)     Ankara
# 9528  Turkish Lira(TL)     Ankara
# 9529  Turkish Lira(TL)     Ankara
# 9530  Turkish Lira(TL)     Ankara
# 9531  Turkish Lira(TL)     Ankara
# 9532  Turkish Lira(TL)     Ankara
# 9533  Turkish Lira(TL)     Ankara
# 9534  Turkish Lira(TL)     Ankara
# 9535  Turkish Lira(TL)     Ankara
# 9536  Turkish Lira(TL)     Ankara
# 9537  Turkish Lira(TL)  ÛÁstanbul
# 9538  Turkish Lira(TL)  ÛÁstanbul
# 9539  Turkish Lira(TL)  ÛÁstanbul
# 9540  Turkish Lira(TL)  ÛÁstanbul
# 9541  Turkish Lira(TL)  ÛÁstanbul
# 9542  Turkish Lira(TL)  ÛÁstanbul
# ...

# %%
gp.get_group(214)
# Out:
#                Currency       City
# 564  Emirati Diram(AED)  Abu Dhabi
# 565  Emirati Diram(AED)  Abu Dhabi
# 566  Emirati Diram(AED)  Abu Dhabi
# 567  Emirati Diram(AED)  Abu Dhabi
# 568  Emirati Diram(AED)  Abu Dhabi
# 569  Emirati Diram(AED)  Abu Dhabi
# 570  Emirati Diram(AED)  Abu Dhabi
# 571  Emirati Diram(AED)  Abu Dhabi
# 572  Emirati Diram(AED)  Abu Dhabi
# 573  Emirati Diram(AED)  Abu Dhabi
# 574  Emirati Diram(AED)  Abu Dhabi
# 575  Emirati Diram(AED)  Abu Dhabi
# 576  Emirati Diram(AED)  Abu Dhabi
# 577  Emirati Diram(AED)  Abu Dhabi
# 578  Emirati Diram(AED)  Abu Dhabi
# 579  Emirati Diram(AED)  Abu Dhabi
# 580  Emirati Diram(AED)  Abu Dhabi
# 581  Emirati Diram(AED)  Abu Dhabi
# 582  Emirati Diram(AED)  Abu Dhabi
# 583  Emirati Diram(AED)  Abu Dhabi
# 584  Emirati Diram(AED)      Dubai
# 585  Emirati Diram(AED)      Dubai
# 586  Emirati Diram(AED)      Dubai
# 587  Emirati Diram(AED)      Dubai
# 588  Emirati Diram(AED)      Dubai
# 589  Emirati Diram(AED)      Dubai
# ...

# %%
gp.get_group(215)
# Out:
#         Currency        City
# 9337  Pounds(£)  Birmingham
# 9338  Pounds(£)  Birmingham
# 9339  Pounds(£)  Birmingham
# 9340  Pounds(£)  Birmingham
# 9341  Pounds(£)  Birmingham
# ...          ...         ...
# 9412  Pounds(£)  Manchester
# 9413  Pounds(£)  Manchester
# 9414  Pounds(£)  Manchester
# 9415  Pounds(£)  Manchester
# 9416  Pounds(£)  Manchester
#
# [80 rows x 2 columns]

# %%
gp.get_group(216)
# Out:
#       Currency            City
# 82   Dollar($)          Albany
# 83   Dollar($)          Albany
# 84   Dollar($)          Albany
# 85   Dollar($)          Albany
# 86   Dollar($)          Albany
# ..         ...             ...
# 558  Dollar($)        Waterloo
# 559  Dollar($)        Waterloo
# 560  Dollar($)        Waterloo
# 561  Dollar($)         Weirton
# 562  Dollar($)  Winchester Bay
#
# [434 rows x 2 columns]

# %% [markdown]
# ### Creating Country column from country code

# %%
# 1. India
# 14. Australia
# 30. Brazil
# 37. Canada
# 94. Indonesia
# 148.newzealand
# 162.philippines
# 166.Quatar
# 184.Singapore
# 189.South Africa
# 191.Sri Lanka
# 208.Turkey
# 214.Abu Dhabi
# 215.Uk
# 216.USA

# %%
country_map = {
    1: "India",
    14: "Australia",
    30: "Brazil",
    37: "Canada",
    94: "Indonesia",
    148: "NewZealand",
    162: "Philippines",
    166: "Quatar",
    184: "Singapore",
    189: "South Africa",
    191: "Sri Lanka",
    208: "Turkey",
    214: "Abu Dhabi",
    215: "UK",
    216: "USA"
    
}

# %%
data["Country"] = data["Country Code"].map(country_map)

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data["Locality"]
# Out:
# 0        Century City Mall, Poblacion, Makati City
# 1       Little Tokyo, Legaspi Village, Makati City
# 2       Edsa Shangri-La, Ortigas, Mandaluyong City
# 3           SM Megamall, Ortigas, Mandaluyong City
# 4           SM Megamall, Ortigas, Mandaluyong City
#                            ...
# 9546                                      Karakí_y
# 9547                                     Koôuyolu
# 9548                                   Kuruí_eôme
# 9549                                   Kuruí_eôme
# 9550                                          Moda
# Name: Locality, Length: 9551, dtype: object

# %%
sns.boxplot(data[numerical_features[0]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 sns.boxplot(data[numerical_features[0]])
#
# NameError: name 'numerical_features' is not defined

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
features_to_drop = ["Restaurant ID","Longitude","Latitude","Locality","Locality Verbose","Address","Country Code"]
data.drop(columns=features_to_drop, axis=1, inplace=True)

# %%
data.head()
# Out:
#           Restaurant Name              City                          Cuisines  \
# 0        Le Petit Souffle       Makati City        French, Japanese, Desserts
# 1        Izakaya Kikufuji       Makati City                          Japanese
# 2  Heat - Edsa Shangri-La  Mandaluyong City  Seafood, Asian, Filipino, Indian
# 3                    Ooma  Mandaluyong City                   Japanese, Sushi
# 4             Sambo Kojin  Mandaluyong City                  Japanese, Korean
#
#    Average Cost for two          Currency Has Table booking  \
# 0                  1100  Botswana Pula(P)               Yes
# 1                  1200  Botswana Pula(P)               Yes
# 2                  4000  Botswana Pula(P)               Yes
# 3                  1500  Botswana Pula(P)                No
# 4                  1500  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu  Price range  \
# ...

# %%
data.shape
# Out:
# (9551, 15)

# %%
res = data.duplicated()

# %%
res = list(res)

# %%
data["Country"].value_counts()
# Out:
# India           8652
# USA              434
# UK                80
# Brazil            60
# Abu Dhabi         60
# South Africa      60
# NewZealand        40
# Turkey            34
# Australia         24
# Philippines       22
# Indonesia         21
# Singapore         20
# Quatar            20
# Sri Lanka         20
# Canada             4
# Name: Country, dtype: int64

# %%
duplicated_columns = data.columns[data.columns.duplicated()]

# %%
duplicated_columns
# Out:
# Index([], dtype='object')

# %%
du = data.columns.duplicated()

# %%
du
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %% [markdown]
# # Zomato Restaurants Ratings Analysis

# %% [markdown]
# # Dataset Description :
#
# ## Columns
# - **Restaurant Id**: Unique identifier for each restaurant.
# - **Restaurant Name**: The name of the restaurant.
# - **Country Code**: The country in which the restaurant is located.
# - **City**: The city in which the restaurant is located.
# - **Address**: The street address of the restaurant.
# - **Locality**: The specific location within the city.
# - **Locality Verbose**: A detailed description of the locality.
# - **Longitude**: The longitude coordinate of the restaurant's location.
# - **Latitude**: The latitude coordinate of the restaurant's location.
# - **Cuisines**: The types of cuisines offered by the restaurant.
# - **Average Cost for Two**: The cost for two people in different currencies (local currency).
# - **Currency**: The currency used in the country.
# - **Has Table Booking**: Whether the restaurant offers table booking (yes/no).
# - **Has Online Delivery**: Whether the restaurant offers online delivery (yes/no).
# - **Is Delivering**: Whether the restaurant is currently delivering (yes/no).
# - **Switch to Order Menu**: Whether the restaurant allows switching to an order menu (yes/no).
# - **Price Range**: The range of prices for food.
# - **Aggregate Rating**: The average rating out of 5.
# - **Rating Color**: The color representation of the average rating.
# - **Rating Text**: Textual representation of the rating.
# - **Votes**: The number of ratings given by customers.
#
# ## Use Cases
# - Analyze the distribution of restaurants across countries and cities.
# - Explore the types of cuisines available in different locations.
# - Investigate the relationship between pricing and ratings.
# - Predict restaurant ratings based on various factors.
# - Visualize restaurant data on maps using longitude and latitude coordinates.
#
# ## Data Source
# [https://www.kaggle.com/datasets/shrutimehta/zomato-restaurants-data?select=zomato.csv]

# %% [markdown]
# ### Importing the necessary libraries (pandas, numpy, matplotlib, seaborn, warnings)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Reading the dataset

# %%
data = pd.read_csv("Data/zomato.csv", encoding = "latin-1")

# %%
original_data = data.copy()

# %% [markdown]
# ### Viewing the top five records

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ### viewing the last five records

# %%
data.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...     Karakí_y
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...    Koôuyolu
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakí_y, ÛÁstanbul  28.977392  41.022793
# ...

# %% [markdown]
# ### Exploring the features in a dataset

# %%
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# ### Exploring the shape of the dataset

# %%
data.shape
# Out:
# (9551, 21)

# %% [markdown]
# ### Checking for null values

# %%
data.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ### Insights :
#  - Out of **21** features **1** feature named **(Cuisines)** has a missing values of **(9)**

# %% [markdown]
# ### Checking for datatypes

# %%
data.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %% [markdown]
# ### Exploring the unique features

# %%
data.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# dtype: int64

# %% [markdown]
# ### Checking for duplicated values in the features

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Insights:
#  - There are no duplicated features **(0)**

# %% [markdown]
# ### Adding new feature (Country)

# %%
country_map = {
    1: "India",
    14: "Australia",
    30: "Brazil",
    37: "Canada",
    94: "Indonesia",
    148: "NewZealand",
    162: "Philippines",
    166: "Quatar",
    184: "Singapore",
    189: "South Africa",
    191: "Sri Lanka",
    208: "Turkey",
    214: "Abu Dhabi",
    215: "UK",
    216: "USA"
    
}

# %%
data["Country"] = data["Country Code"].map(country_map)

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ### Checking for duplicated records after adding Country feature

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### dropping the unwanted features

# %%
features_to_drop = ["Restaurant ID","Longitude","Latitude","Locality","Locality Verbose"]
data.drop(columns=features_to_drop, axis=1, inplace=True)

# %%
data.drop(columns=["Address"], axis=1, inplace=True)

# %%
data.drop(columns=["Country Code"], axis=1, inplace=True)

# %%
data.head()
# Out:
#           Restaurant Name              City                          Cuisines  \
# 0        Le Petit Souffle       Makati City        French, Japanese, Desserts
# 1        Izakaya Kikufuji       Makati City                          Japanese
# 2  Heat - Edsa Shangri-La  Mandaluyong City  Seafood, Asian, Filipino, Indian
# 3                    Ooma  Mandaluyong City                   Japanese, Sushi
# 4             Sambo Kojin  Mandaluyong City                  Japanese, Korean
#
#    Average Cost for two          Currency Has Table booking  \
# 0                  1100  Botswana Pula(P)               Yes
# 1                  1200  Botswana Pula(P)               Yes
# 2                  4000  Botswana Pula(P)               Yes
# 3                  1500  Botswana Pula(P)                No
# 4                  1500  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu  Price range  \
# ...

# %%
data.shape
# Out:
# (9551, 15)

# %% [markdown]
# ### Checking for duplicated records after dropping unwanted features from the dataset

# %%
res = data.duplicated().reset_index()

# %%
res[res[0] == True].sum()
# Out:
# index    289479
# 0            43
# dtype: int64

# %% [markdown]
# ### Insights :
#  - There are **43** duplicated records

# %% [markdown]
# ### Dropping duplicated records

# %%
data = data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Exploring numerical and categorical features

# %%
numerical_features = [feature for feature in data.columns if data[feature].dtypes != object]

# %%
numerical_features
# Out:
# ['Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
categorical_features = [feature for feature in data.columns if data[feature].dtypes == object]

# %%
categorical_features
# Out:
# ['Restaurant Name',
#  'City',
#  'Cuisines',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Rating color',
#  'Rating text',
#  'Country']

# %%
print(f"Number of numerical features : {len(numerical_features)}")
print(f"Number of categorical features : {len(categorical_features)}")
# Out:
# Number of numerical features : 4
# Number of categorical features : 11

# %% [markdown]
# ### Insights :
#  - Out of **15** features - **4** features are **numerical features** and **11** features are **categorical features**

# %% [markdown]
# ### Removing Missing values using mode

# %%
mode_value = data["Cuisines"].mode()[0]
data["Cuisines"].fillna(mode_value,inplace=True)

# %%
data.isnull().sum()
# Out:
# Restaurant Name         0
# City                    0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# ### Outlier Detection

# %%
count = 1
plt.figure(figsize=(16,13))
for feature in numerical_features:
    plt.subplot(2,2,count)
    sns.distplot(data[feature])
    count+=1   
plt.tight_layout()
plt.show()

# %%
count = 1
plt.figure(figsize=(16,13))
for feature in numerical_features:
    plt.subplot(2,2,count)
    sns.boxplot(data[feature])
    plt.title(f"{feature}")
    count+=1  
    plt.title(f'{feature}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## EDA(Exploratory Data Analysis)

# %% [markdown]
# ### Distribution of restaurants across countries and cities

# %%
country_rank_list = data.groupby("Country")["Votes"].sum().reset_index()

# %%
country_rank_list
# Out:
#          Country    Votes
# 0      Abu Dhabi    29611
# 1      Australia     2674
# 2         Brazil     1177
# 3         Canada      412
# 4          India  1187070
# 5      Indonesia    16214
# 6     NewZealand     9721
# 7    Philippines     8963
# 8         Quatar     3276
# 9      Singapore      638
# 10  South Africa    18910
# 11     Sri Lanka     2929
# 12        Turkey    14670
# 13            UK    16439
# 14           USA   185848

# %%
country_rank_list = country_rank_list.sort_values(
    by="Votes", 
    ascending=False
)

# %%
country_rank_list
# Out:
#          Country    Votes
# 4          India  1187070
# 14           USA   185848
# 0      Abu Dhabi    29611
# 10  South Africa    18910
# 13            UK    16439
# 5      Indonesia    16214
# 12        Turkey    14670
# 6     NewZealand     9721
# 7    Philippines     8963
# 8         Quatar     3276
# 11     Sri Lanka     2929
# 1      Australia     2674
# 2         Brazil     1177
# 9      Singapore      638
# 3         Canada      412

# %%
top_five_voted_countries = country_rank_list.head(5)

# %%
top_five_voted_countries
# Out:
#          Country    Votes
# 4          India  1187070
# 14           USA   185848
# 0      Abu Dhabi    29611
# 10  South Africa    18910
# 13            UK    16439

# %%
least_five_voted_countries = country_rank_list.tail(5)

# %%
least_five_voted_countries
# Out:
#       Country  Votes
# 11  Sri Lanka   2929
# 1   Australia   2674
# 2      Brazil   1177
# 9   Singapore    638
# 3      Canada    412

# %%
maximum_voted_country = country_rank_list.head(1)

# %%
maximum_voted_country
# Out:
#   Country    Votes
# 4   India  1187070

# %%
minimum_voted_country  = country_rank_list.sort_values(by="Votes").head(1)

# %%
minimum_voted_country
# Out:
#   Country  Votes
# 3  Canada    412

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(18,13))
plt.subplot(2,2,1)
axis_1 = sns.barplot(x='Country', y='Votes', data=top_five_voted_countries)
plt.title("Top Five Voted Countries")
plt.subplot(2,2,2)
axis_2 = sns.barplot(x='Country', y='Votes', data=least_five_voted_countries)
plt.title("Least Five Voted Countries")
plt.subplot(2,2,3)
axis_3 = sns.barplot(x='Country', y='Votes', data=maximum_voted_country, width=0.2)
plt.title("Country with Highest Reviews")
plt.subplot(2,2,4)
axis_4 = sns.barplot(x='Country', y='Votes', data=minimum_voted_country, width=0.2)
plt.title("Country with Lowest Reviews")
plt.show()

# %% [markdown]
# ### Observation :
#  - From the above observations, **India** and the **USA** have the **maximum** number of customers across the globe.
#  - The country with the maximum number of customers is **India**.
#  - The country with the minimum number of customers is **Canada**.

# %% [markdown]
# ### Cities with maximum reviews from India

# %%
grouped_data = data.groupby("Country")

# %%
reviews_from_india = grouped_data.get_group("India")

# %%
reviews_from_india
# Out:
#                             Restaurant Name   City  \
# 624                              Jahanpanah   Agra
# 625                     Rangrezz Restaurant   Agra
# 626                 Time2Eat - Mama Chicken   Agra
# 627   Chokho Jeeman Marwari Jain Bhojanalya   Agra
# 628                          Pinch Of Spice   Agra
# ...                                     ...    ...
# 9271                               D Cabana  Vizag
# 9272                               Kaloreez  Vizag
# 9273                                Plot 17  Vizag
# 9274                       Vista - The Park  Vizag
# 9275               Flying Spaghetti Monster  Vizag
#
#                                                Cuisines  Average Cost for two  \
# 624                               North Indian, Mughlai                   850
# 625                               North Indian, Mughlai                   700
# 626                                        North Indian                   500
# ...

# %%
reviews_from_indian_cities = reviews_from_india.groupby("City")

# %%
votings_from_indian_cities = reviews_from_indian_cities["Votes"].sum()

# %%
votings_from_indian_cities = votings_from_indian_cities.reset_index()

# %%
votings_from_indian_cities.sort_values(
    by="Votes",
    ascending = False,
    inplace = True
    
)

# %%
votings_from_indian_cities.head()
# Out:
#          City   Votes
# 31  New Delhi  628262
# 15    Gurgaon  132155
# 32      Noida   73478
# 5   Bangalore   56115
# 22    Kolkata   44593

# %%
top_five_voted_indian_cities = votings_from_indian_cities.head(5)

# %%
top_five_voted_indian_cities
# Out:
#          City   Votes
# 31  New Delhi  628262
# 15    Gurgaon  132155
# 32      Noida   73478
# 5   Bangalore   56115
# 22    Kolkata   44593

# %%
reviews_from_india
# Out:
#                             Restaurant Name   City  \
# 624                              Jahanpanah   Agra
# 625                     Rangrezz Restaurant   Agra
# 626                 Time2Eat - Mama Chicken   Agra
# 627   Chokho Jeeman Marwari Jain Bhojanalya   Agra
# 628                          Pinch Of Spice   Agra
# ...                                     ...    ...
# 9271                               D Cabana  Vizag
# 9272                               Kaloreez  Vizag
# 9273                                Plot 17  Vizag
# 9274                       Vista - The Park  Vizag
# 9275               Flying Spaghetti Monster  Vizag
#
#                                                Cuisines  Average Cost for two  \
# 624                               North Indian, Mughlai                   850
# 625                               North Indian, Mughlai                   700
# 626                                        North Indian                   500
# ...

# %% [markdown]
# ### Overall Rating Categories in india

# %%
reviews_from_india.head()
# Out:
#                            Restaurant Name  City  \
# 624                             Jahanpanah  Agra
# 625                    Rangrezz Restaurant  Agra
# 626                Time2Eat - Mama Chicken  Agra
# 627  Chokho Jeeman Marwari Jain Bhojanalya  Agra
# 628                         Pinch Of Spice  Agra
#
#                            Cuisines  Average Cost for two            Currency  \
# 624           North Indian, Mughlai                   850  Indian Rupees(Rs.)
# 625           North Indian, Mughlai                   700  Indian Rupees(Rs.)
# 626                    North Indian                   500  Indian Rupees(Rs.)
# 627                      Rajasthani                   400  Indian Rupees(Rs.)
# 628  North Indian, Chinese, Mughlai                  1000  Indian Rupees(Rs.)
#
#     Has Table booking Has Online delivery Is delivering now  \
# 624                No                  No                No
# 625                No                  No                No
# ...

# %%
rating = reviews_from_india[["City","Aggregate rating","Rating color","Rating text"]]

# %% [markdown]
# ### Cities With Zero Poor Ratings,Zero Not Rated Ratings And Excellent Ratings

# %%
excellent_rating = rating[(rating["Aggregate rating"]>=4.7) & (rating["Aggregate rating"]<5.0) & (rating["Rating text"] != "Poor") & (rating["Rating text"] != "Not rated")]

# %%
excellent_rating = rating[(rating["Rating text"] != "Poor") & (rating["Rating text"] != "Not rated") & (rating["Rating text"] == "Excellent")]

# %%
excellent_rating.head()
# Out:
#           City  Aggregate rating Rating color Rating text
# 637       Agra               4.9   Dark Green   Excellent
# 646  Ahmedabad               4.5   Dark Green   Excellent
# 653  Ahmedabad               4.6   Dark Green   Excellent
# 660  Ahmedabad               4.5   Dark Green   Excellent
# 727  Bangalore               4.7   Dark Green   Excellent

# %%
excellent_rating_cities = excellent_rating[["City","Rating text"]]

# %%
excellent_rating_cities
# Out:
#               City Rating text
# 637           Agra   Excellent
# 646      Ahmedabad   Excellent
# 653      Ahmedabad   Excellent
# 660      Ahmedabad   Excellent
# 727      Bangalore   Excellent
# ...            ...         ...
# 9195  Secunderabad   Excellent
# 9216      Vadodara   Excellent
# 9228      Vadodara   Excellent
# 9256         Vizag   Excellent
# 9262         Vizag   Excellent
#
# [116 rows x 2 columns]

# %%
excellent_rating_cities = excellent_rating_cities.groupby("City").count()

# %%
excellent_rating_cities = excellent_rating_cities.sort_values(
    by="Rating text",
    ascending = False
)

# %% [markdown]
# ### Top Cities With Excellent Ratings

# %%
top_five_excellent_rating_cities = excellent_rating_cities.head(5)

# %%
top_five_excellent_rating_cities = top_five_excellent_rating_cities.reset_index()

# %%
top_five_excellent_rating_cities
# Out:
#         City  Rating text
# 0  New Delhi           28
# 1    Gurgaon           12
# 2  Bangalore            9
# 3    Chennai            6
# 4        Goa            6

# %% [markdown]
# ### Cities With Zero Poor Ratings,Zero Not Rated Very And Good Ratings

# %%
very_good_rating = rating[(rating["Rating text"] != "Poor") & (rating["Rating text"] != "Not rated") & (rating["Rating text"] == "Very Good")]

# %%
very_good_rating.reset_index(inplace=True) 
very_good_rating = very_good_rating[["City","Rating text"]]

# %%
very_good_rating = very_good_rating.groupby("City").count()

# %%
very_good_rating = very_good_rating.sort_values(
    by="Rating text",
    ascending = False
)

# %% [markdown]
# ### Top Cities With Very Good Rating

# %%
very_good_rating = very_good_rating.head()

# %%
very_good_rating = very_good_rating.reset_index()

# %%
very_good_rating
# Out:
#         City  Rating text
# 0  New Delhi          300
# 1    Gurgaon           83
# 2      Noida           27
# 3   Guwahati           15
# 4       Pune           14

# %% [markdown]
# ### Cities With Zero Poor Ratings,Zero Not Rated And Good Ratings

# %%
good_rating = rating[(rating["Rating text"] != "Poor") & (rating["Rating text"] != "Not rated") & (rating["Rating text"] == "Good")]

# %%
good_rating.reset_index(inplace=True) 
good_rating = good_rating[["City","Rating text"]]

# %%
good_rating = good_rating.groupby("City").count()

# %%
good_rating = good_rating.sort_values(
    by="Rating text",
    ascending = False
)

# %% [markdown]
# ### Top Cities With Good Ratings

# %%
good_rating = good_rating.head()

# %%
good_rating = good_rating.reset_index()

# %%
good_rating
# Out:
#         City  Rating text
# 0  New Delhi         1128
# 1    Gurgaon          257
# 2      Noida          173
# 3  Faridabad           22
# 4  Mangalore           18

# %% [markdown]
# ### Cities With Zero Poor Ratings,Zero Not Rated And Average Ratings

# %%
average_rating = rating[(rating["Rating text"] != "Poor") & (rating["Rating text"] != "Not rated") & (rating["Rating text"] == "Average")]

# %%
average_rating.reset_index(inplace=True) 
average_rating = average_rating[["City","Rating text"]]

# %%
average_rating = average_rating.groupby("City").count()

# %%
average_rating = average_rating.sort_values(
    by="Rating text",
    ascending = False
)

# %% [markdown]
# ### Top Cities With Average Ratings

# %%
average_rating = average_rating.head()

# %%
average_rating = average_rating.reset_index()

# %%
average_rating
# Out:
#         City  Rating text
# 0  New Delhi         2489
# 1    Gurgaon          504
# 2      Noida          448
# 3  Faridabad          123
# 4  Ghaziabad           18

# %% [markdown]
# ### Cities With Poor Ratings

# %%
poor_rating = rating[(rating["Rating text"] == "Poor")]

# %%
poor_rating.reset_index(inplace=True) 
poor_rating = poor_rating[["City","Rating text"]]

# %%
poor_rating = poor_rating.groupby("City").count()

# %%
poor_rating = poor_rating.sort_values(
    by="Rating text",
    ascending = False
)

# %% [markdown]
# ### Top Cities With Poor Ratings

# %%
poor_rating = poor_rating.head()

# %%
poor_rating = poor_rating.reset_index()

# %%
poor_rating
# Out:
#         City  Rating text
# 0  New Delhi           97
# 1      Noida           45
# 2    Gurgaon           34
# 3  Faridabad            2
# 4  Ghaziabad            1

# %% [markdown]
# ### Cities With Not Ratings

# %%
not_rated_rating = rating[(rating["Rating text"] == "Not rated")]

# %%
not_rated_rating.reset_index(inplace=True) 
not_rated_rating = not_rated_rating[["City","Rating text"]]

# %%
not_rated_rating = not_rated_rating.groupby("City").count()

# %%
not_rated_rating = not_rated_rating.sort_values(
    by="Rating text",
    ascending = False
)

# %% [markdown]
# ### Top Not Rated Cities

# %%
not_rated_rating = not_rated_rating.head()

# %%
not_rated_rating = not_rated_rating.reset_index()

# %%
not_rated_rating
# Out:
#         City  Rating text
# 0  New Delhi         1408
# 1      Noida          370
# 2    Gurgaon          224
# 3  Faridabad           99
# 4  Ghaziabad            2

# %% [markdown]
# ### Ratings Categories

# %%
category = {
    "Dark Green":"Excellent",
    "Green":"Very Good",
    "Yellow":"Good",
    "Orange":"Average",
    "Red":"Poor",
    "White":"Not rated"
}

# %%
rating_group = rating.groupby("Rating color").count()

# %%
rating_group = rating_group.reset_index()

# %%
rating_group["Rating category"] = rating_group["Rating color"].map(category)

# %%
overall_ratings = rating_group

# %%
overall_ratings
# Out:
#   Rating color  City  Aggregate rating  Rating text Rating category
# 0   Dark Green   116               116          116       Excellent
# 1        Green   692               692          692       Very Good
# 2       Orange  3671              3671         3671         Average
# 3          Red   180               180          180            Poor
# 4        White  2103              2103         2103       Not rated
# 5       Yellow  1847              1847         1847            Good

# %%
overall_rating = overall_ratings[["Rating category","Aggregate rating"]]

# %%
overall_rating
# Out:
#   Rating category  Aggregate rating
# 0       Excellent               116
# 1       Very Good               692
# 2         Average              3671
# 3            Poor               180
# 4       Not rated              2103
# 5            Good              1847

# %% [markdown]
# ### Ranking Cities Across India with Rating Categories

# %%
rating_categories_by_cities = reviews_from_india.groupby(["City","Rating text"]).size().unstack(fill_value = 0)

# %%
rating_categories_by_cities.reset_index(inplace=True)

# %%
ranked_cities_by_ratings = rating_categories_by_cities.sort_values(
    by = ["Excellent","Very Good","Good","Average","Poor"],
    ascending = [False,False,False,False,False]
)

# %% [markdown]
# ### Cities With Rankings

# %%
ranked_cities_by_ratings
# Out:
# Rating text          City  Average  Excellent  Good  Not rated  Poor  \
# 31              New Delhi     2489         28  1128       1408    97
# 15                Gurgaon      504         12   257        224    34
# 5               Bangalore        0          9     2          0     0
# 9                 Chennai        0          6     2          0     0
# 17              Hyderabad        0          6     2          0     0
# 14                    Goa        0          6     5          0     0
# 22                Kolkata        0          5     4          0     0
# 36                   Pune        0          4     2          0     0
# 23                Lucknow        0          4     4          0     0
# 27                 Mumbai        1          4     7          0     0
# 16               Guwahati        0          3     3          0     0
# 1               Ahmedabad        0          3     5          0     0
# 19                 Jaipur        1          3     4          0     0
# ...

# %% [markdown]
# ### Cities With above average ratings

# %%
cities_with_good_ratings = ranked_cities_by_ratings[["City","Good", "Very Good", "Excellent"]]

# %% [markdown]
# ### Top Five Cities With Above Average Ratings

# %%
cities_with_good_ratings["Total"] = cities_with_good_ratings.sum(axis=1)

# %%
cities_with_good_ratings = cities_with_good_ratings.head(5)
cities_with_good_ratings["Total"] = cities_with_good_ratings.sum(axis=1)
cities_with_good_ratings["Average"] = cities_with_good_ratings.median(axis=1)

# %%
cities_with_good_ratings = cities_with_good_ratings.head()

# %%
cities_with_good_ratings
# Out:
# Rating text       City  Good  Very Good  Excellent  Average   Total
# 31           New Delhi  1128        300         28    300.0  1756.0
# 15             Gurgaon   257         83         12     83.0   435.0
# 5            Bangalore     2          9          9      9.0    29.0
# 9              Chennai     2         12          6      6.0    26.0
# 17           Hyderabad     2         10          6      6.0    24.0

# %% [markdown]
# ### Cities with Zero Poor Ratings

# %%
cities_with_poor_ratings = ranked_cities_by_ratings[["City","Poor"]]

# %%
cities_with_poor_ratings
# Out:
# Rating text          City  Poor
# 31              New Delhi    97
# 15                Gurgaon    34
# 5               Bangalore     0
# 9                 Chennai     0
# 17              Hyderabad     0
# 14                    Goa     0
# 22                Kolkata     0
# 36                   Pune     0
# 23                Lucknow     0
# 27                 Mumbai     0
# 16               Guwahati     0
# 1               Ahmedabad     0
# 19                 Jaipur     0
# 10             Coimbatore     0
# 32                  Noida    45
# 21                  Kochi     0
# 8              Chandigarh     0
# 29                 Nagpur     1
# 7            Bhubaneshwar     0
# 40               Vadodara     0
# 42                  Vizag     0
# 11               Dehradun     0
# 0                    Agra     0
# 6                  Bhopal     0
# 24               Ludhiana     0
# 12              Faridabad     2
# 38           Secunderabad     0
# 18                 Indore     0
# ...

# %%
zero_ratings = cities_with_poor_ratings[cities_with_poor_ratings["Poor"] == 0]

# %%
zero_ratings = zero_ratings.sort_values(
    by="Poor",
    ascending = True
)

# %%
zero_ratings = zero_ratings.groupby("City").count().reset_index()

# %%
zero_ratings
# Out:
# Rating text          City  Poor
# 0               Bangalore     1
# 1                  Indore     1
# 2                  Kanpur     1
# 3                Ludhiana     1
# 4            Secunderabad     1
# 5                   Surat     1

# %% [markdown]
# ### Top Not Rated Cities

# %%
cities_with_not_rated_ratings = ranked_cities_by_ratings[["City","Not rated"]]

# %%
cities_with_not_rated_ratings
# Out:
# Rating text          City  Not rated
# 31              New Delhi       1408
# 15                Gurgaon        224
# 5               Bangalore          0
# 9                 Chennai          0
# 17              Hyderabad          0
# 14                    Goa          0
# 22                Kolkata          0
# 36                   Pune          0
# 23                Lucknow          0
# 27                 Mumbai          0
# 16               Guwahati          0
# 1               Ahmedabad          0
# 19                 Jaipur          0
# 10             Coimbatore          0
# 32                  Noida        370
# 21                  Kochi          0
# 8              Chandigarh          0
# 29                 Nagpur          0
# 7            Bhubaneshwar          0
# 40               Vadodara          0
# 42                  Vizag          0
# 11               Dehradun          0
# 0                    Agra          0
# 6                  Bhopal          0
# ...

# %%
not_rated_cities = cities_with_not_rated_ratings.sort_values(
    by="Not rated",
    ascending = False
)

# %%
not_rated_cities.head()
# Out:
# Rating text       City  Not rated
# 31           New Delhi       1408
# 32               Noida        370
# 15             Gurgaon        224
# 12           Faridabad         99
# 13           Ghaziabad          2

# %%
not_rated_cities = not_rated_cities.head(5)

# %%
not_rated_cities
# Out:
# Rating text       City  Not rated
# 31           New Delhi       1408
# 32               Noida        370
# 15             Gurgaon        224
# 12           Faridabad         99
# 13           Ghaziabad          2

# %% [markdown]
# ### Cities With Zero Not Rated Cities

# %%
zero_not_rated = ranked_cities_by_ratings[["City","Not rated"]]

# %%
zero_not_rated = zero_not_rated[zero_not_rated["Not rated"] == 0]

# %%
zero_not_rated
# Out:
# Rating text          City  Not rated
# 5               Bangalore          0
# 9                 Chennai          0
# 17              Hyderabad          0
# 14                    Goa          0
# 22                Kolkata          0
# 36                   Pune          0
# 23                Lucknow          0
# 27                 Mumbai          0
# 16               Guwahati          0
# 1               Ahmedabad          0
# 19                 Jaipur          0
# 10             Coimbatore          0
# 21                  Kochi          0
# 8              Chandigarh          0
# 29                 Nagpur          0
# 7            Bhubaneshwar          0
# 40               Vadodara          0
# 42                  Vizag          0
# 11               Dehradun          0
# 0                    Agra          0
# 6                  Bhopal          0
# 24               Ludhiana          0
# 38           Secunderabad          0
# 18                 Indore          0
# ...

# %%
top_zero_not_rated_cities = zero_not_rated.head(5)

# %%
top_zero_not_rated_cities
# Out:
# Rating text       City  Not rated
# 5            Bangalore          0
# 9              Chennai          0
# 17           Hyderabad          0
# 14                 Goa          0
# 22             Kolkata          0

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(15,13))
plt.subplot(4,3,1)
sns.barplot(x="City", y="Votes", data=top_five_voted_indian_cities)
plt.title("Top Five Voted Cities In India")
plt.subplot(4,3,2)
plt.pie(
    overall_rating['Aggregate rating'], 
    labels=overall_rating['Rating category'], 
    autopct='%1.1f%%', 
    startangle=120
)
plt.title("Overall Rating Categories In India")
plt.subplot(4,3,3)
sns.barplot(x="City", y="Total", data=cities_with_good_ratings)
plt.title("Top Five Cities With Above Average Ratings In India")
plt.subplot(4,3,4)
sns.barplot(x="City", y="Poor", data=zero_ratings)
plt.title("Top Cities With Zero Poor Ratings In India")
plt.subplot(4,3,5)
sns.barplot(x="City", y="Not rated", data=not_rated_cities)
plt.title("Top Cities With High Not Rated Ratings In India")
plt.subplot(4,3,6)
sns.barplot(x="City", y="Rating text", data=top_five_excellent_rating_cities)
plt.title("Top Cities With Excellent Ratings In India")
plt.subplot(4,3,7)
sns.barplot(x="City", y="Rating text", data=very_good_rating)
plt.title("Top Cities With Very Good Ratings In India")
plt.subplot(4,3,8)
sns.barplot(x="City", y="Rating text", data=good_rating)
plt.title("Top Cities With Good Ratings In India")
plt.subplot(4,3,9)
sns.barplot(x="City", y="Rating text", data=average_rating)
plt.title("Top Cities With Average Ratings In India")
plt.subplot(4,3,10)
sns.barplot(x="City", y="Rating text", data=poor_rating)
plt.title("Top Cities With Poor Ratings In India")
plt.subplot(4,3,11)
sns.barplot(x="City", y="Rating text", data=not_rated_rating)
plt.title("Top Cities With Not rated Ratings In India")
plt.subplot(4,3,12)
sns.countplot(x='City', data=zero_not_rated.tail())
plt.xlabel("City")
plt.ylabel("Count")
plt.title("Cities With Zero Not rated Cities")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
#  - The Overall performance of indian restaurants are Average **(42%)**
#  - Top five cities with highest votings from the customers are **New              Delhi**,**Gurgaon**,**Noida**,**Guwahati**,**Pune**
#  - Top five above average rating cities are **New Delhi**,**Gurgoan**,**Banglore**,**Chennai**,**Hyderabad**
#  - Top five excellent rating cities are **New Delhi**,**Gurgoan**,**Banglore**,**Chennai**,**Goa**
#  - Top five very good rating cities are **New Delhi**,**Gurgoan**,**Noida**,**Guwahati**,**Pune**
#  - Top five good rating cities are **New Delhi**,**Gurgoan**,**Noida**,**Faridabad**,**Manglore**
#  - Top five average rating cities are **New Delhi**,**Gurgoan**,**Noida**,**Faridabad**,**Ghaziabad**
#  - Top five poor rated cities are **New Delhi**,**Noida**,**Gurgoan**,**Faridabad**,**Ghaziabad**
#  - Top five not rated cities are **New Delhi**,**Noida**,**Gurgoan**,**Faridabad**,**Ghaziabad**
#  - Top five cities with zero poor ratings are **Banglore**,**Indore**,**Kanpur**,**Secunderabad**,**Surat**
#  - Top five cities with zero not rated are **Panchkula**,**Nashik**,**Patna**,**Allahabad**,**Aurangabad**

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(40,30))
plt.subplot(2,2,1)
sns.histplot(
    x="Aggregate rating", 
    data=reviews_from_india, 
    hue="City",
    kde=True
)
plt.title("Aggregated Ratings Across India")
plt.show()

# %% [markdown]
# ### Ratings Across Restaurants,Cusines and cities

# %%
reviews_from_india.head()
# Out:
#                            Restaurant Name  City  \
# 624                             Jahanpanah  Agra
# 625                    Rangrezz Restaurant  Agra
# 626                Time2Eat - Mama Chicken  Agra
# 627  Chokho Jeeman Marwari Jain Bhojanalya  Agra
# 628                         Pinch Of Spice  Agra
#
#                            Cuisines  Average Cost for two            Currency  \
# 624           North Indian, Mughlai                   850  Indian Rupees(Rs.)
# 625           North Indian, Mughlai                   700  Indian Rupees(Rs.)
# 626                    North Indian                   500  Indian Rupees(Rs.)
# 627                      Rajasthani                   400  Indian Rupees(Rs.)
# 628  North Indian, Chinese, Mughlai                  1000  Indian Rupees(Rs.)
#
#     Has Table booking Has Online delivery Is delivering now  \
# 624                No                  No                No
# 625                No                  No                No
# ...

# %%
indian_restaurants_data = reviews_from_india[["Restaurant Name","City","Cuisines","Average Cost for two","Price range","Has Table booking","Has Online delivery","Is delivering now","Switch to order menu","Rating text"]]

# %%
indian_restaurants_data.head()
# Out:
#                            Restaurant Name  City  \
# 624                             Jahanpanah  Agra
# 625                    Rangrezz Restaurant  Agra
# 626                Time2Eat - Mama Chicken  Agra
# 627  Chokho Jeeman Marwari Jain Bhojanalya  Agra
# 628                         Pinch Of Spice  Agra
#
#                            Cuisines  Average Cost for two  Price range  \
# 624           North Indian, Mughlai                   850            3
# 625           North Indian, Mughlai                   700            2
# 626                    North Indian                   500            2
# 627                      Rajasthani                   400            2
# 628  North Indian, Chinese, Mughlai                  1000            3
#
#     Has Table booking Has Online delivery Is delivering now  \
# 624                No                  No                No
# 625                No                  No                No
# ...

# %% [markdown]
# ### How many Restaurants has Online Delivery in India ?

# %%
online_delivery = indian_restaurants_data["Has Online delivery"].value_counts().reset_index()

# %%
online_delivery = online_delivery.rename(
    columns = {"index":"Online Delivery","Has Online delivery":"Counts"}
)

# %%
online_delivery
# Out:
#   Online Delivery  Counts
# 0              No    6192
# 1             Yes    2417

# %%
plt.figure(figsize=(16,13))
plt.subplot(2,2,1)
plt.pie(
    online_delivery["Counts"],
    labels = online_delivery["Online Delivery"],
    autopct='%1.1f%%', 
    startangle=120
)
plt.title("Online Delivery")
plt.show()

# %% [markdown]
# ### Observation
#  - In **India**, only **28.1%** of the restaurants offer **online delivery**, while the remaining **71.9%** do not provide this service.

# %% [markdown]
# ### How many Restaurants has table booking in india ?

# %%
table_booking = indian_restaurants_data["Has Table booking"].value_counts().reset_index()

# %%
table_booking = table_booking.rename(
    columns = {"index":"Table Booking","Has Table booking":"Counts"}
)

# %%
table_booking
# Out:
#   Table Booking  Counts
# 0            No    7498
# 1           Yes    1111

# %%
plt.figure(figsize=(16,13))
plt.subplot(2,2,1)
plt.pie(
    table_booking["Counts"],
    labels = table_booking["Table Booking"],
    autopct='%1.1f%%', 
    startangle=120
)
plt.title("Has Table Bookings")
plt.show()

# %% [markdown]
# ### Observation :
#  - In India, only **12.9%** of the restaurants has a table bookings, while the remaining 87.1% do not provide this service.

# %% [markdown]
# ### How many restaurants are delivering right now

# %%
delivering = indian_restaurants_data["Is delivering now"].value_counts().reset_index()

# %%
delivering = delivering.rename(
    columns = {"index":"Delivering","Is delivering now":"Counts"}
)

# %%
plt.figure(figsize=(16,13))
plt.subplot(2,2,1)
plt.pie(
    delivering["Counts"],
    labels = delivering["Delivering"],
    autopct='%1.1f%%', 
    startangle=120
)
plt.title("Is Delivering Rightnow")
plt.show()

# %% [markdown]
# ### Observation:
#  - In india, only **0.4%** of the restaurants are delivering right now, while the rest **99.6%** of the restaurants are not delivering right now

# %% [markdown]
# ### Cuisines Ratings In India

# %%
cuisines_count_india = indian_restaurants_data["Cuisines"].value_counts().reset_index()

# %% [markdown]
# ### Top Rated Cuisines Distribution

# %%
top_10_rated_cuisines_in_india = cuisines_count_india.head(10)

# %%
top_10_rated_cuisines_in_india
# Out:
#                             index  Cuisines
# 0                    North Indian       935
# 1           North Indian, Chinese       510
# 2                       Fast Food       347
# 3                         Chinese       340
# 4           North Indian, Mughlai       334
# 5                            Cafe       262
# 6                          Bakery       216
# 7  North Indian, Mughlai, Chinese       197
# 8                Bakery, Desserts       167
# 9                     Street Food       149

# %%
plt.figure(figsize=(18,13))
plt.subplot(2,2,1)
cs = sns.barplot(
    x = top_10_rated_cuisines_in_india["index"],
    y = top_10_rated_cuisines_in_india["Cuisines"]
)
cs.set_xticklabels(cs.get_xticklabels(),rotation=45);
plt.xlabel("Cuisines")
plt.ylabel("Counts")
plt.title("Top 10 Rated Cuisines Distribution")
plt.show()

# %% [markdown]
# ### Excellent Rating Restaurants

# %%
restaurants_with_excellent_ratings = indian_restaurants_data[indian_restaurants_data["Rating text"]=='Excellent']

# %%
restaurants_with_excellent_ratings
# Out:
#                         Restaurant Name          City  \
# 637                     Sheroes Hangout          Agra
# 646                       Huber & Holly     Ahmedabad
# 653                            Cryo Lab     Ahmedabad
# 660                      Nini's Kitchen     Ahmedabad
# 727    The Fatty Bao - Asian Gastro Bar     Bangalore
# ...                                 ...           ...
# 9195                         Coffee Cup  Secunderabad
# 9216                      22nd Parallel      Vadodara
# 9228  La Quello - Mediterranean Kitchen      Vadodara
# 9256                          Pizza Hut         Vizag
# 9262                    Barbeque Nation         Vizag
#
#                                                Cuisines  Average Cost for two  \
# 637                         Cafe, North Indian, Chinese                     0
# 646                    Ice Cream, Desserts, Continental                   300
# 653                                 Desserts, Ice Cream                   350
# ...

# %%
excellent_rating_restaurants = restaurants_with_excellent_ratings.groupby("Restaurant Name")["Rating text"].count()

# %%
excellent_rating_restaurants = excellent_rating_restaurants.reset_index()

# %%
excellent_rating_restaurants = excellent_rating_restaurants.sort_values(
    by="Rating text",
    ascending = False
)

# %% [markdown]
# ### Top Excellent Rating Restaurants

# %%
top_excellent_rating_restaurants = excellent_rating_restaurants.head()

# %%
top_excellent_rating_restaurants
# Out:
#               Restaurant Name  Rating text
# 6             Barbeque Nation           10
# 1   AB's - Absolute Barbecues            4
# 20                    Chili's            4
# 88                     Twigly            2
# 61                     Onesta            2

# %% [markdown]
# ### Top Excellent Rating Cuisines

# %%
excellent_rating_cuisines = restaurants_with_excellent_ratings["Cuisines"].value_counts().reset_index()

# %%
excellent_rating_cuisines = excellent_rating_cuisines.head(10)

# %%
excellent_rating_cuisines = excellent_rating_cuisines.rename(
    columns = {"index":"Cuisines","Cuisines":"Counts"}
)

# %%
excellent_rating_cuisines
# Out:
#                                 Cuisines  Counts
# 0                           North Indian       7
# 1                              Ice Cream       5
# 2                  North Indian, Mughlai       4
# 3                          Modern Indian       3
# 4                       Bakery, Desserts       3
# 5                                   Cafe       3
# 6     Mexican, American, Tex-Mex, Burger       3
# 7  European, Mediterranean, North Indian       3
# 8                  North Indian, Chinese       3
# 9                              Fast Food       2

# %% [markdown]
# ### Very Good Rating Restaurants

# %%
restaurants_with_very_good_ratings = indian_restaurants_data[indian_restaurants_data["Rating text"]=='Very Good']

# %%
very_good_rating_restaurants = restaurants_with_very_good_ratings.groupby("Restaurant Name")["Rating text"].count()

# %%
very_good_rating_restaurants = very_good_rating_restaurants.reset_index()

# %%
very_good_rating_restaurants = very_good_rating_restaurants.sort_values(
    by="Rating text",
    ascending = False
)

# %% [markdown]
# ### Top Very Good Ratings

# %%
top_very_good_rating_restaurants = very_good_rating_restaurants.head()

# %%
top_very_good_rating_restaurants
# Out:
#      Restaurant Name  Rating text
# 41   Barbeque Nation           12
# 409        Pizza Hut            6
# 201       Farzi Cafe            5
# 340            Mocha            4
# 414     Punjab Grill            4

# %% [markdown]
# ### Top Very Good Rating Cuisines

# %%
very_good_rating_cuisines = restaurants_with_very_good_ratings["Cuisines"].value_counts().reset_index()

# %%
very_good_rating_cuisines = very_good_rating_cuisines.head()

# %%
very_good_rating_cuisines
# Out:
#                    index  Cuisines
# 0  North Indian, Mughlai        25
# 1  North Indian, Chinese        19
# 2                   Cafe        18
# 3           North Indian        16
# 4                Chinese        14

# %%
very_good_rating_cuisines = very_good_rating_cuisines.rename(
    columns = {"index":"Cuisines","Cuisines":"Counts"}
)

# %%
very_good_rating_cuisines
# Out:
#                 Cuisines  Counts
# 0  North Indian, Mughlai      25
# 1  North Indian, Chinese      19
# 2                   Cafe      18
# 3           North Indian      16
# 4                Chinese      14

# %% [markdown]
# ### Good Rating Restaurants

# %%
restaurants_with_good_ratings = indian_restaurants_data[indian_restaurants_data["Rating text"]=='Good']

# %%
good_restaurant_count = restaurants_with_good_ratings.shape[0]

# %%
good_restaurant_count
# Out:
# 1847

# %%
good_rating_restaurants = restaurants_with_good_ratings.groupby("Restaurant Name")["Rating text"].count()

# %%
good_rating_restaurants = good_rating_restaurants.reset_index()

# %%
good_rating_restaurants = good_rating_restaurants.sort_values(
    by="Rating text",
    ascending = False
)

# %% [markdown]
# ### Top Good Ratings

# %%
top_good_rating_restaurants = good_rating_restaurants.head()

# %%
top_good_rating_restaurants
# Out:
#      Restaurant Name  Rating text
# 806       McDonald's           20
# 433   Dunkin' Donuts           16
# 556       Haldiram's           15
# 1184       Starbucks           15
# 682        Keventers           13

# %% [markdown]
# ### Top Good Rating Cuisines

# %%
good_rating_cuisines = restaurants_with_good_ratings["Cuisines"].value_counts().reset_index()

# %%
good_rating_cuisines = good_rating_cuisines.head(10)

# %%
good_rating_cuisines = good_rating_cuisines.rename(
    columns = {"index":"Cuisines","Cuisines":"Counts"}
)

# %%
good_rating_cuisines
# Out:
#                          Cuisines  Counts
# 0                    North Indian      92
# 1                            Cafe      75
# 2           North Indian, Mughlai      71
# 3                       Fast Food      56
# 4           North Indian, Chinese      55
# 5                     Street Food      39
# 6                         Chinese      38
# 7                Bakery, Desserts      31
# 8     Bakery, Desserts, Fast Food      31
# 9  North Indian, Mughlai, Chinese      29

# %% [markdown]
# ### Average Rating Restaurants

# %%
restaurants_with_average_ratings = indian_restaurants_data[indian_restaurants_data["Rating text"]=='Average']

# %%
average_restaurant_count = restaurants_with_average_ratings.shape[0]

# %%
average_restaurant_count
# Out:
# 3671

# %%
average_rating_restaurants = restaurants_with_average_ratings.groupby("Restaurant Name")["Rating text"].count()

# %%
average_rating_restaurants = average_rating_restaurants.reset_index()

# %%
average_rating_restaurants = average_rating_restaurants.sort_values(
    by="Rating text",
    ascending = False
)

# %% [markdown]
# ### Top Average Ratings Restaurants

# %%
top_average_rating_restaurants = average_rating_restaurants.head()

# %%
top_average_rating_restaurants
# Out:
#        Restaurant Name  Rating text
# 430    Cafe Coffee Day           56
# 816     Domino's Pizza           53
# 2399            Subway           43
# 1030  Green Chick Chop           38
# 1543        McDonald's           27

# %% [markdown]
# ### Top Average Rating Cuisines

# %%
average_rating_cuisines = restaurants_with_average_ratings["Cuisines"].value_counts().reset_index()

# %%
average_rating_cuisines = average_rating_cuisines.head(10)

# %%
average_rating_cuisines = average_rating_cuisines.rename(
    columns = {"index":"Cuisines","Cuisines":"Counts"}
)

# %%
average_rating_cuisines
# Out:
#                          Cuisines  Counts
# 0                    North Indian     366
# 1           North Indian, Chinese     303
# 2           North Indian, Mughlai     185
# 3                         Chinese     150
# 4                       Fast Food     150
# 5                            Cafe     129
# 6  North Indian, Mughlai, Chinese     122
# 7                          Bakery      96
# 8                Pizza, Fast Food      77
# 9                Bakery, Desserts      72

# %% [markdown]
# ### Poor Rating Restaurants

# %%
restaurants_with_poor_ratings = indian_restaurants_data[indian_restaurants_data["Rating text"]=='Poor']

# %%
poor_restaurant_count = restaurants_with_poor_ratings.shape[0]

# %%
poor_restaurant_count
# Out:
# 180

# %%
poor_rating_restaurants = restaurants_with_poor_ratings.groupby("Restaurant Name")["Rating text"].count()

# %%
poor_rating_restaurants = poor_rating_restaurants.reset_index()

# %%
poor_rating_restaurants = poor_rating_restaurants.sort_values(
    by="Rating text",
    ascending = False
)

# %% [markdown]
# ### Top Poor Rating Restaurants

# %%
top_poor_rating_restaurants = poor_rating_restaurants.head()

# %%
top_poor_rating_restaurants
# Out:
#         Restaurant Name  Rating text
# 39       Domino's Pizza           12
# 121          Wah Ji Wah            7
# 102              Subway            7
# 86   Pizza Hut Delivery            5
# 94          Sagar Ratna            4

# %% [markdown]
# ### Top Poor Rating Cuisines

# %%
poor_rating_cuisines = restaurants_with_poor_ratings["Cuisines"].value_counts().reset_index()

# %%
poor_rating_cuisines = poor_rating_cuisines.head(10)

# %%
poor_rating_cuisines = poor_rating_cuisines.rename(
    columns = {"index":"Cuisines","Cuisines":"Counts"}
)

# %%
poor_rating_cuisines
# Out:
#                                    Cuisines  Counts
# 0                     North Indian, Chinese      17
# 1                          Pizza, Fast Food      13
# 2                              North Indian      11
# 3            North Indian, Mughlai, Chinese       9
# 4                     North Indian, Mughlai       9
# 5                                   Chinese       8
# 6  American, Fast Food, Salad, Healthy Food       7
# 7       South Indian, North Indian, Chinese       5
# 8                        Chinese, Fast Food       5
# 9                     Biryani, North Indian       4

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(15,13))
plt.subplot(3,3,1)
er = sns.barplot(x="Restaurant Name",y="Rating text",data=top_excellent_rating_restaurants)
plt.title("Top 5 Excellent Rated Restaurants")
er.set_xticklabels(er.get_xticklabels(),rotation=45);
plt.subplot(3,3,2)
vg = sns.barplot(x="Restaurant Name",y="Rating text",data=top_very_good_rating_restaurants)
plt.title("Top 5 Very Good Rated Restaurants")
vg.set_xticklabels(vg.get_xticklabels(),rotation=45);
plt.subplot(3,3,3)
g = sns.barplot(x="Restaurant Name",y="Rating text",data=top_good_rating_restaurants)
plt.title("Top 5 Good Rated Restaurants")
g.set_xticklabels(g.get_xticklabels(),rotation=45);
plt.subplot(3,3,7)
av = sns.barplot(x="Restaurant Name",y="Rating text",data=top_average_rating_restaurants)
plt.title("Top 5 Average Rated Restaurants")
av.set_xticklabels(av.get_xticklabels(),rotation=45);
plt.subplot(3,3,8)
av = sns.barplot(x="Restaurant Name",y="Rating text",data=top_poor_rating_restaurants)
plt.title("Top 5 Poor Rated Restaurants")
av.set_xticklabels(av.get_xticklabels(),rotation=45);
plt.show()

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(16,13))
plt.subplot(2,2,1)
exc = sns.barplot(
    x = "Cuisines",
    y = "Counts",
    data = excellent_rating_cuisines
)
exc.set_xticklabels(exc.get_xticklabels(),rotation=60);
plt.title("Top 10 Excellent Rating Cuisines")
# Out:
# Text(0.5, 1.0, 'Top 10 Excellent Rating Cuisines')

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(16,13))
plt.subplot(2,2,1)
vgc = sns.barplot(
    x = "Cuisines",
    y = "Counts",
    data = very_good_rating_cuisines
)
vgc.set_xticklabels(vgc.get_xticklabels(),rotation=60);
plt.title("Top 10 Very Good Rating Cuisines")
# Out:
# Text(0.5, 1.0, 'Top 10 Very Good Rating Cuisines')

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(16,13))
plt.subplot(2,2,1)
gc = sns.barplot(
    x = "Cuisines",
    y = "Counts",
    data = good_rating_cuisines
)
gc.set_xticklabels(gc.get_xticklabels(),rotation=60);
plt.title("Top 10 Good Rating Cuisines")
# Out:
# Text(0.5, 1.0, 'Top 10 Good Rating Cuisines')

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(16,13))
plt.subplot(2,2,1)
avc = sns.barplot(
    x = "Cuisines",
    y = "Counts",
    data = average_rating_cuisines
)
avc.set_xticklabels(exc.get_xticklabels(),rotation=60);
plt.title("Top 10 Average Rating Cuisines")
# Out:
# Text(0.5, 1.0, 'Top 10 Average Rating Cuisines')

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(16,13))
plt.subplot(2,2,1)
pc = sns.barplot(
    x = "Cuisines",
    y = "Counts",
    data = poor_rating_cuisines
)
pc.set_xticklabels(pc.get_xticklabels(),rotation=60);
plt.title("Top 10 Poor Rating Cuisines")
# Out:
# Text(0.5, 1.0, 'Top 10 Poor Rating Cuisines')
